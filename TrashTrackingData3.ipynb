# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl

# %%
UsPollution = pd.read_csv('uspollution.zip')

# %%
UsPollution.columns
# Out:
# Index(['Unnamed: 0', 'State Code', 'County Code', 'Site Num', 'Address',
#        'State', 'County', 'City', 'Date Local', 'NO2 Units', 'NO2 Mean',
#        'NO2 1st Max Value', 'NO2 1st Max Hour', 'NO2 AQI', 'O3 Units',
#        'O3 Mean', 'O3 1st Max Value', 'O3 1st Max Hour', 'O3 AQI', 'SO2 Units',
#        'SO2 Mean', 'SO2 1st Max Value', 'SO2 1st Max Hour', 'SO2 AQI',
#        'CO Units', 'CO Mean', 'CO 1st Max Value', 'CO 1st Max Hour', 'CO AQI'],
#       dtype='object')

# %%
NYsolidwaste = pd.read_csv('solid-waste-management-facilities.csv')

# %%
NYsolidwaste.head()
# Out:
#               Facility Name                        Location Address  \
# 0         Buffalo BioEnergy                     North America Drive
# 1  Cayuga Regional Digester                  7389 County House Road
# 2         Niagara BioEnergy                           Liberty Drive
# 3        Patterson Farm Inc  1131 Aurelius-Springport Townline Rd.
# 4      Synergy Biogas Plant                        6466 Lemley Road
#
#   Location Address2         City State Zip Code   County  Region  \
# 0               NaN  West Seneca    NY   ?14224     Erie       9
# 1               NaN       Auburn    NY   ?13021   Cayuga       7
# 2               NaN   Wheatfield    NY   ?14304  Niagara       9
# 3               NaN       Auburn    NY   ?13021   Cayuga       7
# 4               NaN    Covington    NY   ?14591  Wyoming       9
#
#    Phone Number                              Owner Name  \
# 0           NaN                Sustainable BioVolt; LLC
# ...

# %%
NYsolidwaste.columns
# Out:
# Index(['Facility Name', 'Location Address', 'Location Address2', 'City',
#        'State', 'Zip Code', 'County', 'Region', 'Phone Number', 'Owner Name',
#        'Owner Type', 'Activity Desc', 'Activity Number', 'Active',
#        'East Coordinate', 'North Coordinate', 'Accuracy Code', 'Waste Types',
#        'Regulatory Status', 'Authorization Number', 'Authorization Issue Date',
#        'Expiration Date', 'Location'],
#       dtype='object')

# %%
UnIndustrialWaste = pd.read_csv('UNdata_IndustrialWaste.csv')

# %%
UnIndustrialWaste.head()
# Out:
#   Country or Area        Commodity - Transaction    Year        Unit  \
# 0       Australia  Industrial Waste - Production  2016.0  Terajoules
# 1       Australia  Industrial Waste - Production  2015.0  Terajoules
# 2       Australia  Industrial Waste - Production  2014.0  Terajoules
# 3       Australia  Industrial Waste - Production  2013.0  Terajoules
# 4       Australia  Industrial Waste - Production  2012.0  Terajoules
#
#    Quantity  Quantity Footnotes
# 0    4841.0                 NaN
# 1    4035.0                 NaN
# 2    4298.0                 NaN
# 3    4022.0                 NaN
# 4    4029.0                 NaN

# %%
UnIndustrialWaste.columns
# Out:
# Index(['Country or Area', 'Commodity - Transaction', 'Year', 'Unit',
#        'Quantity', 'Quantity Footnotes'],
#       dtype='object')

# %%
UnIndustrialWaste;

# %%
UnIndustrialWaste['Country or Area'].unique()
# Out:
# array(['Australia', 'Austria', 'Belarus', 'Belgium', 'Bulgaria', 'Canada',
#        'China', 'Croatia', 'Cyprus', 'Czechia', 'Finland', 'France',
#        'Germany', 'Greece', 'Hungary', 'Iceland', 'Ireland', 'Italy',
#        'Japan', 'Korea, Republic of', 'Latvia', 'Lithuania', 'Luxembourg',
#        'Malawi', 'Mexico', 'Norway', 'Poland', 'Portugal',
#        'Republic of Moldova', 'Romania', 'Russian Federation', 'Serbia',
#        'Serbia and Montenegro', 'Slovakia', 'Slovenia', 'Spain', 'Sweden',
#        'Switzerland', 'Turkey', 'United Kingdom', 'United States',
#        'fnSeqID', '1'], dtype=object)

# %%
UnIndustrialWaste['Commodity - Transaction'].unique()
# Out:
# array(['Industrial Waste - Production',
#        'Industrial Waste - Final energy consumption',
#        'Industrial Waste - Consumption by manufacturing, construction and non-fuel industry',
#        'Industrial Waste - Consumption by chemical and petrochemical',
#        'Industrial Waste - Consumption by other manuf., const. and non-fuel ind.',
#        'Industrial Waste - Consumption by food and tobacco ',
#        'Industrial waste - Total energy supply',
#        'Industrial waste - Final consumption',
#        'Industrial Waste - Transformation',
#        'Industrial waste - Transformation in electricity, CHP and heat plants',
#        'Industrial Waste - Transformation in electricity plants - main activity producers',
#        'Industrial Waste - Transformation in electricity plants - autoproducers',
#        'Industrial Waste - Transformation in CHP plants - main activity producers',
#        'Industrial Waste - Transformation in CHP plants - autoproducers',
# ...

# %%
UIWTransactionDeInteresse=['Industrial Waste - Production',
                           'Industrial Waste - Transformation',
                           'Industrial waste - Final consumption' ]

# %%
UIW=UnIndustrialWaste.loc[UnIndustrialWaste['Commodity - Transaction'].isin(UIWTransactionDeInteresse)]

# %%
print(np.shape(UnIndustrialWaste))
print(np.shape(UIW))
# Out:
# (9225, 6)
# (1994, 6)

# %%
UIW.head()
# Out:
#   Country or Area        Commodity - Transaction    Year        Unit  \
# 0       Australia  Industrial Waste - Production  2016.0  Terajoules
# 1       Australia  Industrial Waste - Production  2015.0  Terajoules
# 2       Australia  Industrial Waste - Production  2014.0  Terajoules
# 3       Australia  Industrial Waste - Production  2013.0  Terajoules
# 4       Australia  Industrial Waste - Production  2012.0  Terajoules
#
#    Quantity  Quantity Footnotes
# 0    4841.0                 NaN
# 1    4035.0                 NaN
# 2    4298.0                 NaN
# 3    4022.0                 NaN
# 4    4029.0                 NaN

# %%
UIW[]
# Out:
# array([nan,  1.])

# %%
UnIndustrialWaste['Country or Area'].unique()
# Out:
# array(['Australia', 'Austria', 'Belarus', 'Belgium', 'Bulgaria', 'Canada',
#        'China', 'Croatia', 'Cyprus', 'Czechia', 'Finland', 'France',
#        'Germany', 'Greece', 'Hungary', 'Iceland', 'Ireland', 'Italy',
#        'Japan', 'Korea, Republic of', 'Latvia', 'Lithuania', 'Luxembourg',
#        'Malawi', 'Mexico', 'Norway', 'Poland', 'Portugal',
#        'Republic of Moldova', 'Romania', 'Russian Federation', 'Serbia',
#        'Serbia and Montenegro', 'Slovakia', 'Slovenia', 'Spain', 'Sweden',
#        'Switzerland', 'Turkey', 'United Kingdom', 'United States',
#        'fnSeqID', '1'], dtype=object)

# %%
PaisesDeInteresse=['China','United States','Turkey', 'Mexico','Russian Federation']

# %%
UIW=UIW.loc[UIW['Country or Area'].isin(PaisesDeInteresse)]

# %%
UIW['prod-transf']=UIW[]

# %%
np.shape(UIW)
# Out:
# (209, 6)

# %%
UIWProducao=UIW.loc[UIW['Commodity - Transaction']=='Industrial Waste - Production']
UIWTransformacao=UIW.loc[UIW['Commodity - Transaction']=='Industrial Waste - Transformation']

# %%
UIWProducao=UIWProducao.drop(columns=['Commodity - Transaction'])
UIWTransformacao=UIWTransformacao.drop(columns=['Commodity - Transaction'])

# %%
UIWTransformacao=UIWTransformacao.drop(columns=['Quantity Footnotes'])
UIWProducao=UIWProducao.drop(columns=['Quantity Footnotes'])

# %%
UIWTransformacao=UIWTransformacao.reset_index()
UIWProducao=UIWProducao.reset_index()

print(UIWProducao.head())
print(UIWTransformacao.head())
# Out:
#    index Country or Area    Year        Unit  Quantity
# 0      0       Australia  2016.0  Terajoules    4841.0
# 1      1       Australia  2015.0  Terajoules    4035.0
# 2      2       Australia  2014.0  Terajoules    4298.0
# 3      3       Australia  2013.0  Terajoules    4022.0
# 4      4       Australia  2012.0  Terajoules    4029.0
#    index Country or Area    Year        Unit  Quantity
# 0    237         Austria  2015.0  Terajoules    5908.0
# 1    238         Austria  2014.0  Terajoules    5473.0
# 2    239         Austria  2013.0  Terajoules    6664.0
# 3    240         Austria  2012.0  Terajoules    7303.0
# 4    241         Austria  2011.0  Terajoules    6430.0

# %%
UIWProducao=UIWProducao.loc[UIWProducao['Country or Area'].isin(PaisesDeInteresse)]
UIWTransformacao=UIWTransformacao.loc[UIWTransformacao['Country or Area'].isin(PaisesDeInteresse)]

# %%
UIWTransformacao=UIWTransformacao.drop(columns=['index'])
UIWProducao=UIWProducao.drop(columns=['index'])

# %%
UIWProducao=UIWProducao.reset_index()
UIWTransformacao=UIWTransformacao.reset_index()
UIWTransformacao=UIWTransformacao.drop(columns=['index'])
UIWProducao=UIWProducao.drop(columns=['index'])

# %%
UIWProducao['prod-transf']=UIWProducao['Quantity']-UIWTransformacao['Quantity']

# %%
UIWProducao
# Out:
#          Country or Area        Commodity - Transaction    Year        Unit  \
# 1639               China  Industrial Waste - Production  2015.0  Terajoules
# 1640               China  Industrial Waste - Production  2014.0  Terajoules
# 1641               China  Industrial Waste - Production  2013.0  Terajoules
# 1642               China  Industrial Waste - Production  2012.0  Terajoules
# 1643               China  Industrial Waste - Production  2011.0  Terajoules
# 1644               China  Industrial Waste - Production  2010.0  Terajoules
# 4823              Mexico  Industrial Waste - Production  2016.0  Terajoules
# 4824              Mexico  Industrial Waste - Production  2015.0  Terajoules
# 4825              Mexico  Industrial Waste - Production  2014.0  Terajoules
# 4826              Mexico  Industrial Waste - Production  2013.0  Terajoules
# 4827              Mexico  Industrial Waste - Production  2012.0  Terajoules
# ...

# %%
UIWTransformacao
# Out:
#    Country or Area    Year        Unit  Quantity
# 0            China  2015.0  Terajoules  201339.7
# 1            China  2014.0  Terajoules  234875.8
# 2            China  2013.0  Terajoules  220797.0
# 3            China  2012.0  Terajoules  198239.0
# 4            China  2011.0  Terajoules  187350.0
# 5            China  2010.0  Terajoules  158114.5
# 6            Italy  2015.0  Terajoules    1452.0
# 7            Italy  2014.0  Terajoules    1147.0
# 8            Italy  2013.0  Terajoules    1234.0
# 9            Italy  2012.0  Terajoules    1875.0
# 10           Italy  2011.0  Terajoules    1815.0
# 11           Italy  2010.0  Terajoules    1673.0
# 12           Italy  2009.0  Terajoules    2273.0
# 13           Italy  2008.0  Terajoules    2128.0
# 14           Italy  2007.0  Terajoules    2662.0
# 15           Italy  2006.0  Terajoules    2646.0
# 16           Italy  2005.0  Terajoules    2309.0
# 17           Italy  2004.0  Terajoules    4225.0
# ...

# %%
fig, ax = plt.subplots()

index = np.arange(n_groups)
bar_width = 0.35

opacity = 0.4
error_config = {'ecolor': '0.3'}

rects1 = ax.bar(index, means_men, bar_width,
                alpha=opacity, color='b',
                yerr=std_men, error_kw=error_config,
                label='Men')

rects2 = ax.bar(index + bar_width, means_women, bar_width,
                alpha=opacity, color='r',
                yerr=std_women, error_kw=error_config,
                label='Women')

ax.set_xlabel('Group')
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(('A', 'B', 'C', 'D', 'E'))
ax.legend()
# Out:
# Empty DataFrame
# Columns: [Country or Area, Commodity - Transaction, Year, Unit, Quantity, Quantity Footnotes]
# Index: []

# %%
UIWTransactionDeInteresse
# Out:
# ['Industrial Waste - Production',
#  'Industrial Waste - Transformation',
#  'Industrial waste - Final consumption']

# %%
np.shape(UIWProducao)
# Out:
# (86, 6)

# %%
UIWProducao.Year.unique()
# Out:
# array([2015., 2014., 2013., 2012., 2011., 2010., 2016., 2009., 2008.,
#        2007., 2006., 2005., 2004., 2003., 2002., 2001., 2000., 1999.,
#        1998., 1997., 1996., 1995., 1994., 1993., 1992., 1991., 1990.])

# %%
AnosDeInteresse=[2015.]

# %%
UIWProducao=UIWProducao.loc[UIWProducao['Year'].isin(AnosDeInteresse)]
UIWTransformacao=UIWTransformacao.loc[UIWTransformacao['Year'].isin(AnosDeInteresse)]

# %%
UIWProducao.Year.unique()
# Out:
# array([2015.])

# %%
np.shape(UIWProducao)
# Out:
# (30, 6)

# %%
UIWProducao
# Out:
#          Country or Area        Commodity - Transaction    Year        Unit  \
# 1639               China  Industrial Waste - Production  2015.0  Terajoules
# 4824              Mexico  Industrial Waste - Production  2015.0  Terajoules
# 6570  Russian Federation  Industrial Waste - Production  2015.0  Terajoules
# 8518              Turkey  Industrial Waste - Production  2015.0  Terajoules
# 8796       United States  Industrial Waste - Production  2015.0  Terajoules
#
#       Quantity  Quantity Footnotes
# 1639  200665.6                 NaN
# 4824     472.0                 NaN
# 6570  198890.0                 NaN
# 8518    2489.0                 NaN
# 8796   50686.0                 NaN

# %%
UIWTransformacao
# Out:
#          Country or Area            Commodity - Transaction    Year  \
# 1645               China  Industrial Waste - Transformation  2015.0
# 4832              Mexico  Industrial Waste - Transformation  2015.0
# 6611  Russian Federation  Industrial Waste - Transformation  2015.0
# 8534              Turkey  Industrial Waste - Transformation  2015.0
# 8822       United States  Industrial Waste - Transformation  2015.0
#
#             Unit  Quantity  Quantity Footnotes
# 1645  Terajoules  201339.7                 NaN
# 4832  Terajoules     472.0                 NaN
# 6611  Terajoules  148534.0                 NaN
# 8534  Terajoules    2489.0                 NaN
# 8822  Terajoules   33475.0                 NaN

# %%
x=UIWTransformacao[UIWTransformacao['Country or Area']=='China']['Quantity']
y=UIWTransformacao[UIWTransformacao['Country or Area']=='China']['Year']
plt.title('Transformação de Resíduo Industrial na China')
plt.ylabel('Terajoules')
mpl.style.use('seaborn')
plt.bar(y,x)
# Out:
# <Container object of 6 artists>

# %%
x=UIWProducao[UIWProducao['Country or Area']=='China']['Quantity']
y=UIWProducao[UIWProducao['Country or Area']=='China']['Year']
plt.title('Produção de Resíduo Industrial na China')
plt.ylabel('Terajoules')
mpl.style.use('seaborn')
plt.bar(y,x)
# Out:
# <Container object of 6 artists>

# %%
x=UIWProducao[UIWProducao['Country or Area']=='United States']['Quantity']
y=UIWProducao[UIWProducao['Country or Area']=='United States']['Year']
plt.title('Produção de Resíduo Industrial nos Estados Unidos')
plt.ylabel('Terajoules')
mpl.style.use('seaborn')
plt.bar(y,x)
# Out:
# <Container object of 6 artists>

# %%
x=UIWTransformacao[UIWTransformacao['Country or Area']=='United States']['Quantity']
y=UIWTransformacao[UIWTransformacao['Country or Area']=='United States']['Year']
plt.title('Transformação de Resíduo Industrial nos Estados Unidos')
plt.ylabel('Terajoules')
mpl.style.use('seaborn')
plt.bar(y,x)
# Out:
# <Container object of 6 artists>

# %%
x=UIWProducao[UIWProducao['Country or Area']=='Mexico']['Quantity']
y=UIWProducao[UIWProducao['Country or Area']=='Mexico']['Year']
plt.title('Produção de Resíduo Industrial no Mexico')
plt.ylabel('Terajoules')
mpl.style.use('seaborn')
plt.bar(y,x)
# Out:
# <Container object of 9 artists>

# %%
x=UIWTransformacao[UIWTransformacao['Country or Area']=='Mexico']['Quantity']
y=UIWTransformacao[UIWTransformacao['Country or Area']=='Mexico']['Year']
plt.title('Produção de Resíduo Industrial no Mexico')
plt.ylabel('Terajoules')
mpl.style.use('seaborn')
plt.bar(y,x)
# Out:
# <Container object of 6 artists>

# %%
x=UIWProducao[UIWProducao['Country or Area']=='Turkey']['Quantity']
y=UIWProducao[UIWProducao['Country or Area']=='Turkey']['Year']
plt.title('Produção de Resíduo Industrial na Turquia')
plt.ylabel('Terajoules')
mpl.style.use('seaborn')
plt.bar(y,x)
# Out:
# <Container object of 6 artists>

# %%
x=UIWProducao[UIWProducao['Country or Area']=='Italy']['Quantity']
y=UIWProducao[UIWProducao['Country or Area']=='Italy']['Year']
plt.ylabel('Terajoules')
plt.bar(y,x)
mpl.style.use('seaborn')
plt.title('Produção de Resíduo Industrial na Italia')
# Out:
# Text(0.5,1,'Produção de Resíduo Industrial na Italia')

# %%
x=UIWTransformacao[UIWTransformacao['Country or Area']=='Italy']['Quantity']
y=UIWTransformacao[UIWTransformacao['Country or Area']=='Italy']['Year']
plt.ylabel('Terajoules')
plt.bar(y,x)
mpl.style.use('seaborn')
plt.title('Transformação de Resíduo Industrial na Italia')
# Out:
# Text(0.5,1,'Transformação de Resíduo Industrial na Italia')

# %%
UIW.columns
# Out:
# Index(['Country or Area', 'Commodity - Transaction', 'Year', 'Unit',
#        'Quantity', 'Quantity Footnotes'],
#       dtype='object')

# %% [markdown]
# Média internacional de custo de energia elétrica (FIRJAN 2015) - 275,74 / MWh
#                                                                - 76592,30 / Terajoule

# %%
UIW['Commodity - Transaction'].unique()
# Out:
# array(['Industrial Waste - Production',
#        'Industrial Waste - Transformation',
#        'Industrial waste - Total energy supply',
#        'Industrial Waste - Final energy consumption',
#        'Industrial Waste - Consumption by manufacturing, construction and non-fuel industry',
#        'Industrial Waste - Consumption by chemical and petrochemical',
#        'Industrial waste - Final consumption'], dtype=object)

# %%
a=UIW.loc[UIW['Country or Area']=='United States']
a=a.loc[a['Year']==2005]
print(a)
# Out:
#      Country or Area                            Commodity - Transaction  \
# 8806   United States                      Industrial Waste - Production
# 8832   United States                  Industrial Waste - Transformation
# 8970   United States        Industrial Waste - Final energy consumption
# 8993   United States  Industrial Waste - Consumption by manufacturin...
# 9018   United States  Industrial Waste - Consumption by chemical and...
# 9184   United States             Industrial waste - Total energy supply
# 9210   United States               Industrial waste - Final consumption
#
#         Year        Unit  Quantity  Quantity Footnotes
# 8806  2005.0  Terajoules  104030.0                 NaN
# 8832  2005.0  Terajoules   44571.0                 NaN
# 8970  2005.0  Terajoules   59459.0                 NaN
# 8993  2005.0  Terajoules   59051.0                 NaN
# 9018  2005.0  Terajoules   28955.0                 NaN
# 9184  2005.0  Terajoules  104030.0                 NaN
# ...

# %%
x=a['Commodity - Transaction']
y=a['Quantity']
#y=['Produção', 'Transformação', 'Consumo final de energia', 
  # 'Consumo por manufatura e construção', 'Consumo por Químicos e Petroquímicos',
  #]

plt.bar(x,y)

plt.xticks(x, rotation=90)
plt.ylabel('Terajoules')
plt.title('Energia de Resíduo Industrial - EUA - 2005')
plt.show()

# %%
a=UIW.loc[UIW['Country or Area']=='China']
a=a.loc[a['Year']==2012]
print(a)
# Out:
#      Country or Area            Commodity - Transaction    Year        Unit  \
# 1642           China      Industrial Waste - Production  2012.0  Terajoules
# 1648           China  Industrial Waste - Transformation  2012.0  Terajoules
#
#       Quantity  Quantity Footnotes
# 1642  198687.4                 NaN
# 1648  198239.0                 NaN

# %%
x=a['Commodity - Transaction']
y=a['Quantity']
#y=['Produção', 'Transformação', 'Consumo final de energia', 
  # 'Consumo por manufatura e construção', 'Consumo por Químicos e Petroquímicos',
  #]

plt.bar(x,y)

plt.xticks(x, rotation=90)
plt.ylabel('Terajoules')
plt.title('Energia de Resíduo Industrial - EUA - 2005')
plt.show()

# %%
PaisesDeInteresse
# Out:
# ['China', 'United States', 'Italy', 'Turkey', 'Mexico']

# %%
1 terajoule - 76.586,78 reais

# %%
sera = pd.read_csv('ten00108.tsv.gz')

# %%
sera
# Out:
#     unit    hazard   nace_r2   waste  \
# 0      T  HAZ_NHAZ  TOTAL_HH   TOTAL
# 1      T  HAZ_NHAZ  TOTAL_HH   TOTAL
# 2      T  HAZ_NHAZ  TOTAL_HH   TOTAL
# 3      T  HAZ_NHAZ  TOTAL_HH   TOTAL
# 4      T  HAZ_NHAZ  TOTAL_HH   TOTAL
# 5      T  HAZ_NHAZ  TOTAL_HH   TOTAL
# 6      T  HAZ_NHAZ  TOTAL_HH   TOTAL
# 7      T  HAZ_NHAZ  TOTAL_HH   TOTAL
# 8      T  HAZ_NHAZ  TOTAL_HH   TOTAL
# 9      T  HAZ_NHAZ  TOTAL_HH   TOTAL
# 10     T  HAZ_NHAZ  TOTAL_HH   TOTAL
# 11     T  HAZ_NHAZ  TOTAL_HH   TOTAL
# 12     T  HAZ_NHAZ  TOTAL_HH   TOTAL
# 13     T  HAZ_NHAZ  TOTAL_HH   TOTAL
# 14     T  HAZ_NHAZ  TOTAL_HH   TOTAL
# 15     T  HAZ_NHAZ  TOTAL_HH   TOTAL
# 16     T  HAZ_NHAZ  TOTAL_HH   TOTAL
# 17     T  HAZ_NHAZ  TOTAL_HH   TOTAL
# 18     T  HAZ_NHAZ  TOTAL_HH   TOTAL
# 19     T  HAZ_NHAZ  TOTAL_HH   TOTAL
# 20     T  HAZ_NHAZ  TOTAL_HH   TOTAL
# 21     T  HAZ_NHAZ  TOTAL_HH   TOTAL
# 22     T  HAZ_NHAZ  TOTAL_HH   TOTAL
# 23     T  HAZ_NHAZ  TOTAL_HH   TOTAL
# ...

# %% [markdown]
# x1=UIWProducao[UIWProducao['Country or Area']=='China']
# #x1=x1[x1['Year']==2015]['Quantity']
# #y1=UIWProducao[UIWProducao['Country or Area']=='China']['Year']
# #y1=y1[y1['Year']==2015]
#
# x=UIWProducao[UIWProducao['Country or Area']=='United States']['Quantity']
# #x=x[x['Year']==2015]['Quantity']
# #y=UIWProducao[UIWProducao['Country or Area']=='United States']['Year']
# #y=y[y['Year']==2015]
# #plt.title('Produção de Resíduo Industrial nos Estados Unidos')
# #plt.ylabel('Terajoules')
# #mpl.style.use('seaborn')
# #plt.bar(y,x)

# %%
x1=UIWProducao[UIWProducao['Country or Area']=='China']
#x1=x1[x1['Year']==2015]['Quantity']
#y1=UIWProducao[UIWProducao['Country or Area']=='China']['Year']
#y1=y1[y1['Year']==2015]

x=UIWProducao[UIWProducao['Country or Area']=='United States']
#x=x[x['Year']==2015]['Quantity']
#y=UIWProducao[UIWProducao['Country or Area']=='United States']['Year']
#y=y[y['Year']==2015]
#plt.title('Produção de Resíduo Industrial nos Estados Unidos')
#plt.ylabel('Terajoules')
#mpl.style.use('seaborn')
#plt.bar(y,x)

y1=UIWTransformacao[UIWTransformacao['Country or Area']=='China']
#x1=x1[x1['Year']==2015]['Quantity']
#y1=UIWProducao[UIWProducao['Country or Area']=='China']['Year']
#y1=y1[y1['Year']==2015]

y=UIWTransformacao[UIWTransformacao['Country or Area']=='United States']

# %%
a=x1[x1['Year']==2015]
aa=y1[y1['Year']==2015]

# %%
b=x[x['Year']==2015]
bb=y[y['Year']==2015]

# %%
print(a)
print(b)
print(aa)
print(bb)
# Out:
#   Country or Area    Year        Unit  Quantity  prod-transf
# 0           China  2015.0  Terajoules  200665.6       -674.1
#    Country or Area    Year        Unit  Quantity  prod-transf
# 60   United States  2015.0  Terajoules   50686.0       8945.0
#   Country or Area    Year        Unit  Quantity
# 0           China  2015.0  Terajoules  201339.7
#    Country or Area    Year        Unit  Quantity
# 55   United States  2015.0  Terajoules   33475.0

# %%
x=[a['Quantity'],aa['Quantity'],b['Quantity'],bb['Quantity']]
y=['Produção China', 'Transformação China', 'Produção EUA', 'Transformação EUA',]

# %%
x
# Out:
# [0    200665.6
#  Name: Quantity, dtype: float64, 0    201339.7
#  Name: Quantity, dtype: float64, 60    50686.0
#  Name: Quantity, dtype: float64, 55    33475.0
#  Name: Quantity, dtype: float64]

# %%
plt.title('Resíduo Industrial - 2015', fontsize=20)
plt.ylabel('Terajoules')
mpl.style.use('seaborn')
sns.barplot(y,x)
plt.rcParams["axes.labelsize"] = 17
plt.tick_params(labelsize=10)

# %%
x
# Out:
# [0    200665.6
#  Name: Quantity, dtype: float64, 0    201339.7
#  Name: Quantity, dtype: float64, 60    50686.0
#  Name: Quantity, dtype: float64, 55    33475.0
#  Name: Quantity, dtype: float64]

# %%
x=[200665.6,201339.7,50686.0,33475.0]

# %%
f=(1/0.4)*29700000

# %%
f
# Out:
# 74250000.0

# %%
sns.piechart(f,29700000)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-257-417b2eced71f> in <module>()
# ----> 1 sns.piechart(f,29700000)
#
# AttributeError: module 'seaborn' has no attribute 'piechart'

# %%
labels = 'Resíduo encaminhado ', 'Resíduo perdido'
sizes = [71035000, 41700000]
colors = ['green', 'red']
explode = (0.1, 0)  # explode 1st slice
 
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
        autopct='%1.1f%%', shadow=True, startangle=140)
plt.title('RSU - abrelpe - 2015', fontsize=20)


plt.rcParams["axes.labelsize"] = 17
plt.tick_params(labelsize=10)
plt.axis('equal')


mpl.style.use('seaborn')
plt.show()

# %%
UIW
# Out:
#      Country or Area               Commodity - Transaction    Year  \
# 0          Australia         Industrial Waste - Production  2016.0
# 1          Australia         Industrial Waste - Production  2015.0
# 2          Australia         Industrial Waste - Production  2014.0
# 3          Australia         Industrial Waste - Production  2013.0
# 4          Australia         Industrial Waste - Production  2012.0
# 5          Australia         Industrial Waste - Production  2011.0
# 6          Australia         Industrial Waste - Production  2010.0
# 7          Australia         Industrial Waste - Production  2009.0
# 8          Australia         Industrial Waste - Production  2008.0
# 9          Australia         Industrial Waste - Production  2007.0
# 10         Australia         Industrial Waste - Production  2006.0
# 11         Australia         Industrial Waste - Production  2005.0
# 12         Australia         Industrial Waste - Production  2004.0
# ...

# %%
usUIW=UnIndustrialWaste[UnIndustrialWaste['Country or Area']=='United States']

# %%
usUIW['Commodity - Transaction'].unique()
# Out:
# array(['Industrial Waste - Production',
#        'Industrial Waste - Transformation',
#        'Industrial waste - Transformation in electricity, CHP and heat plants',
#        'Industrial Waste - Transformation in electricity plants - main activity producers',
#        'Industrial Waste - Transformation in electricity plants - autoproducers',
#        'Industrial Waste - Transformation in CHP plants - main activity producers',
#        'Industrial Waste - Transformation in CHP plants - autoproducers',
#        'Industrial Waste - Final energy consumption',
#        'Industrial Waste - Consumption by manufacturing, construction and non-fuel industry',
#        'Industrial waste - Consumption by iron and steel',
#        'Industrial Waste - Consumption by chemical and petrochemical',
#        'Industrial Waste - Consumption by other manuf., const. and non-fuel ind.',
#        'Industrial Waste - Consumption by non-metallic minerals ',
# ...

# %%
chinaUIW=UnIndustrialWaste[UnIndustrialWaste['Country or Area']=='China']

# %%
usUIW2015 = usUIW[usUIW['Year']==2015]

# %%
chinaUIW2015=chinaUIW[chinaUIW['Year']==2015]

# %%
chinaUIW2015=chinaUIW2015.drop([1669])

# %%
usUIW2015=usUIW2015.drop([8796,8822,8960,9174,9200])

# %%
usUIW2015
# Out:
#      Country or Area                            Commodity - Transaction  \
# 8848   United States  Industrial waste - Transformation in electrici...
# 8874   United States  Industrial Waste - Transformation in electrici...
# 8891   United States  Industrial Waste - Transformation in electrici...
# 8917   United States  Industrial Waste - Transformation in CHP plant...
# 8934   United States  Industrial Waste - Transformation in CHP plant...
# 8983   United States  Industrial Waste - Consumption by manufacturin...
# 9008   United States  Industrial Waste - Consumption by chemical and...
# 9025   United States  Industrial Waste - Consumption by other manuf....
# 9048   United States  Industrial Waste - Consumption by non-metallic...
# 9065   United States  Industrial Waste - Consumption by food and tob...
# 9082   United States  Industrial Waste - Consumption by paper, pulp ...
# 9099   United States  Industrial Waste - Consumption by wood and woo...
# ...

# %%
x=pd.Series(usUIW2015['Quantity'] )
y=pd.Series(usUIW2015['Commodity - Transaction'] )

# %%
ddf=pd.concat([x, y], axis=1)
ddf=ddf.drop([9048,9099,9116, 9139, 9159,9065])

# %%
ddf

x=ddf['Quantity']
y=ddf['Commodity - Transaction']

# %%
novoy=pd.Series(np.zeros(len(y)))
for i in range(0,len(y)):
    novoy.iloc[i]=re.sub('Industrial Waste', ' ', str(y.iloc[i]))

# %%
#novoy=pd.Series(np.zeros(len(y)))
for i in range(0,len(y)):
    novoy.iloc[i]=re.sub('Industrial waste', ' ', str(novoy.iloc[i]))

# %%
import re

# %%
df=pd.DataFrame(y,x)

# %%
novoy
# Out:
# 0       - Transformation in electricity, CHP and hea...
# 1       - Transformation in electricity plants - mai...
# 2       - Transformation in electricity plants - aut...
# 3       - Transformation in CHP plants - main activi...
# 4        - Transformation in CHP plants - autoproducers
# 5       - Consumption by manufacturing, construction...
# 6           - Consumption by chemical and petrochemical
# 7       - Consumption by other manuf., const. and no...
# 8               - Consumption by non-metallic minerals
# 9                    - Consumption by food and tobacco
# 10               - Consumption by paper, pulp and print
# 11             - Consumption by wood and wood products
# 12      - Consumption not elsewhere specified (indus...
# 13                               - Consumption by other
# 14        - Consumption by commerce and public services
# dtype: object

# %%
df
# Out:
#          Commodity - Transaction
# Quantity
# 50686.0                      NaN
# 33475.0                      NaN
# 33475.0                      NaN
# 7622.0                       NaN
# 8702.0                       NaN
# 9866.0                       NaN
# 7285.0                       NaN
# 17211.0                      NaN
# 17211.0                      NaN
# 5868.0                       NaN
# 11343.0                      NaN
# 1.0                          NaN
# 256.0                        NaN
# 11086.0                      NaN
# 0.0                          NaN
# 0.0                          NaN
# 0.0                          NaN
# 0.0                          NaN
# 50686.0                      NaN
# 17211.0                      NaN

# %%
#print(x)
x=x.reset_index()
print(x)
x=x.drop(columns=['index'])
x=x['Quantity']
# Out:
#    index  Quantity
# 0   8848   33475.0
# 1   8874    7622.0
# 2   8891    8702.0
# 3   8917    9866.0
# 4   8934    7285.0
# 5   8983   17211.0
# 6   9008    5868.0
# 7   9025   11343.0
# 8   9082   11086.0

# %%
#x=pd.Series(x['Quantity'])
#x=x.drop(columns='index')
print(x)
print(novoy)
# Out:
# 0    33475.0
# 1     7622.0
# 2     8702.0
# 3     9866.0
# 4     7285.0
# 5    17211.0
# 6     5868.0
# 7    11343.0
# 8    11086.0
# Name: Quantity, dtype: float64
# 0      - Transformation in electricity, CHP and hea...
# 1      - Transformation in electricity plants - mai...
# 2      - Transformation in electricity plants - aut...
# 3      - Transformation in CHP plants - main activi...
# 4       - Transformation in CHP plants - autoproducers
# 5      - Consumption by manufacturing, construction...
# 6          - Consumption by chemical and petrochemical
# 7      - Consumption by other manuf., const. and no...
# 8               - Consumption by paper, pulp and print
# dtype: object

# %%
sns.set_color_codes("pastel")
sns.barplot(x,novoy)
plt.ylabel('Residue Destinations US 2015')
plt.xlabel('Terajoules')
plt.rcParams["axes.labelsize"] = 17
plt.tick_params(labelsize=14)

# %%
UnIndustrialWaste['Commodity - Transaction'].unique()
# Out:
# array(['Industrial Waste - Production',
#        'Industrial Waste - Final energy consumption',
#        'Industrial Waste - Consumption by manufacturing, construction and non-fuel industry',
#        'Industrial Waste - Consumption by chemical and petrochemical',
#        'Industrial Waste - Consumption by other manuf., const. and non-fuel ind.',
#        'Industrial Waste - Consumption by food and tobacco ',
#        'Industrial waste - Total energy supply',
#        'Industrial waste - Final consumption',
#        'Industrial Waste - Transformation',
#        'Industrial waste - Transformation in electricity, CHP and heat plants',
#        'Industrial Waste - Transformation in electricity plants - main activity producers',
#        'Industrial Waste - Transformation in electricity plants - autoproducers',
#        'Industrial Waste - Transformation in CHP plants - main activity producers',
#        'Industrial Waste - Transformation in CHP plants - autoproducers',
# ...

# %%
x1=chinaUIW2015['Quantity'] 
y1=chinaUIW2015['Commodity - Transaction']

# %%
x=[    33475.0,
    7622.0,
     8702.0,
    9866.0,
    7285.0,
   17211.0,
    5868.0,
   11343.0,
   11086.0]

# %%
for i in range(0, len(x)):
    x[i]=(x[i]*76600)/1000000000

# %%
x
# Out:
# [0.0011524860153367602,
#  0.0002624122004151392,
#  0.0002995947215970272,
#  0.00033966921664861763,
#  0.00025080987667597596,
#  0.0005925447889458096,
#  0.0002020250317549248,
#  0.00039051975719088484,
#  0.0003816716942800096]
